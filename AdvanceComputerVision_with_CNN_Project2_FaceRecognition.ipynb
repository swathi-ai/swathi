# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1UXScsVx_Wni_JuDdB8LeTnM6jsPfIwkW)
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# # Instructions
# - Some parts of the code are already done for you
# - You need to execute all the cells
# - You need to add the code where ever you see `"#### Add your code here ####"`
# - Marks are mentioned along with the cells

# %% [markdown]
# # Face recognition
# Task is to recognize a faces

# %% [markdown]
# ### Dataset
# **Aligned Face Dataset from Pinterest**
#
# This dataset contains 10.770 images for 100 people. All images are taken from 'Pinterest' and      aligned using dlib library.

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.3.0'

# %% [markdown]
# #### Mount Google drive if you are using google colab
# - We recommend using Google Colab as you can face memory issues and longer runtimes while running on local

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g5c7UffyQi43TrgbwayVVGjfGAGEjHlfFUAJurclS7pke1_gX-dQPc

# %% [markdown]
# #### Change current working directory to project folder (1 mark)

# %%
# %cd /content/drive/My Drive/ACV/Project
# Out:
# /content/drive/My Drive/ACV/Project

# %% [markdown]
# ### Extract the zip file (2 marks)
# - Extract Aligned Face Dataset from Pinterest.zip

# %%
#!unzip "/content/drive/My Drive/ACV/Project/Aligned Face Dataset.zip" -d "/content/drive/My Drive/ACV/Project"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner57_1691.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner58_1668.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner59_1653.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner5_1638.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner60_1650.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner61_1725.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner62_1698.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner64_1722.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner65_1682.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner66_1688.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner68_1651.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner69_1662.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner70_1642.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner71_1751.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner72_1726.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner73_1738.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner74_1694.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner74_1695.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner76_1743.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner77_1697.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner7_1678.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner80_1696.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner84_1683.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner85_1749.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner87_1700.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner90_1724.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner95_1670.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner97_1639.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner98_1712.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner99_1745.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sophie Turner/Sophie Turner9_1675.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell0.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell1.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell10.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell11.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell12.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell13.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell14.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell15.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell16.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell17.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell18.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell19.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell2.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell20.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell21.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell22.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell23.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell24.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell25.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell26.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell27.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell28.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell29.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell3.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell30.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell31.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell32.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell33.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell34.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell35.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell36.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell37.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell38.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell39.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell4.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell40.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell41.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell42.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell43.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell44.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell45.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell46.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell47.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell48.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell49.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell5.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell50.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell51.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell52.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell53.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell54.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell55.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell56.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell57.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell58.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell59.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell6.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell60.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell61.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell62.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell63.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell64.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell65.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell66.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell67.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell68.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell69.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell7.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell70.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell71.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell72.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell73.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell74.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell75.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell76.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell77.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell78.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell79.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell8.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell80.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell81.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell82.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell83.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell84.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell85.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell86.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell87.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell88.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell89.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell9.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell90.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell91.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell92.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell93.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell94.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell95.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell96.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell97.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell98.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Stephen Amell/Stephen Amell99.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai101_682.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai102_678.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai104_732.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai105_703.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai107_667.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai108_735.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai109_720.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai10_714.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai111_704.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai113_688.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai121_753.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai124_673.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai131_719.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai132_747.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai135_689.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai137_677.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai138_706.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai143_730.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai146_687.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai147_731.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai149_711.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai150_746.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai153_727.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai154_718.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai155_671.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai156_724.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai157_675.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai158_745.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai15_702.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai160_728.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai162_723.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai164_700.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai165_749.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai166_676.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai169_738.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pichai170_692.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Sundar Pichai/Sundar Pich
jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero24_2405.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero28_2411.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero2_2385.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero30_2334.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero31_2358.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero32_2350.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero33_2344.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero36_2399.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero37_2373.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero43_2408.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero49_2400.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero50_2343.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_Ursula Corbero/Ursula Corbero52_2391.jpg
# ...
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face45.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face46.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face47.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face48.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face49.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face5.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face50.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face51.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face52.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face53.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face54.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face55.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face56.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face57.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face58.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face59.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face6.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face60.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face61.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face62.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face63.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face64.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face65.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face66.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face67.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face68.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face69.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face7.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face70.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face71.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face72.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face73.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face74.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face75.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face76.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face77.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face78.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face79.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face8.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face80.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face81.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face82.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face83.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face84.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face85.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face86.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face87.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face88.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face89.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face9.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face90.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face91.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face92.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face93.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face94.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face95.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face96.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face97.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face98.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_tom holland face/tom holland face99.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya0.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya1.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya10.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya100.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya101.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya102.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya103.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya104.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya105.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya106.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya107.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya108.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya11.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya12.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya13.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya14.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya15.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya16.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya17.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya18.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya19.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya2.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya20.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya21.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya22.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya23.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya24.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya25.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya26.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya27.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya28.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya29.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya3.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya30.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya31.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya32.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya33.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya34.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya35.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya36.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya37.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya38.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya39.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya4.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya40.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya41.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya42.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya43.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya44.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya45.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya46.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya47.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya48.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya49.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya5.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya50.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya51.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya52.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya53.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya54.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya55.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya56.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya57.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya58.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya59.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya6.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya60.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya61.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya62.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya63.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya64.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya65.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya66.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya67.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya68.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya69.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya7.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya70.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya71.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya72.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya73.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya74.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya75.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya76.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya77.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya78.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya79.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya8.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya80.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya81.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya82.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya83.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya84.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya85.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya86.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya87.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya88.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya89.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya9.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya90.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya91.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya92.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya93.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya94.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya95.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya96.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya97.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya98.jpg
#   inflating: /content/drive/My Drive/ACV/Project/pins/PINS/pins_zendaya/zendaya99.jpg

# %%
# !ls  PINS | wc
# Out:
#     100     217    1975

# %% [markdown]
# ### Function to load images
# - Define a function to load the images from the extracted folder and map each image with person id

# %%
import numpy as np
import os

class IdentityMetadata():
    def __init__(self, base, name, file):
        # print(base, name, file)
        # dataset base directory
        self.base = base
        # identity name
        self.name = name
        # image file name
        self.file = file

    def __repr__(self):
        return self.image_path()

    def image_path(self):
        return os.path.join(self.base, self.name, self.file) 
    
def load_metadata(path):
    metadata = []
    for i in os.listdir(path):
        for f in os.listdir(os.path.join(path, i)):
            # Check file extension. Allow only jpg/jpeg' files.
            ext = os.path.splitext(f)[1]
            if ext == '.jpg' or ext == '.jpeg':
                metadata.append(IdentityMetadata(path, i, f))
    return np.array(metadata)

# metadata = load_metadata('images')
metadata = load_metadata('PINS')

# %% [markdown]
# ### Define function to load image
# - Define a function to load image from the metadata

# %%
import cv2
def load_image(path):
    img = cv2.imread(path, 1)
    # OpenCV loads images with color channels
    # in BGR order. So we need to reverse them
    return img[...,::-1]

# %% [markdown]
# #### Load a sample image (2 marks)
# - Load one image using the function "load_image"

# %%
import matplotlib.pyplot as plt

# %%
#### Add your code here ####
img_arr = load_image('PINS/pins_zendaya/zendaya91.jpg')

plt.figure(figsize=(5,5))
plt.imshow(img_arr)
plt.show()

# %% [markdown]
# ### VGG Face model
# - Here we are giving you the predefined model for VGG face

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ZeroPadding2D, Convolution2D, MaxPooling2D, Dropout, Flatten, Activation

def vgg_face():	
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(Convolution2D(4096, (7, 7), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(4096, (1, 1), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(2622, (1, 1)))
    model.add(Flatten())
    model.add(Activation('softmax'))
    return model

# %% [markdown]
# #### Load the model (2 marks)
# - Load the model defined above
# - Then load the given weight file named "vgg_face_weights.h5"

# %%
model = vgg_face()
#### Add your code here ####

# %%
model.load_weights('vgg_face_weights.h5')

# %% [markdown]
# ### Get vgg_face_descriptor

# %%
from tensorflow.keras.models import Model
vgg_face_descriptor = Model(inputs=model.layers[0].input, outputs=model.layers[-2].output)

# %% [markdown]
# ### Generate embeddings for each image in the dataset
# - Given below is an example to load the first image in the metadata and get its embedding vector from the pre-trained model.

# %%
# Get embedding vector for first image in the metadata using the pre-trained model

img_path = metadata[0].image_path()
img = load_image(img_path)

# Normalising pixel values from [0-255] to [0-1]: scale RGB values to interval [0,1]
img = (img / 255.).astype(np.float32)

img = cv2.resize(img, dsize = (224,224))
print(img.shape)

# Obtain embedding vector for an image
# Get the embedding vector for the above image using vgg_face_descriptor model and print the shape 

embedding_vector = vgg_face_descriptor.predict(np.expand_dims(img, axis=0))[0]
print(embedding_vector.shape)
# Out:
# (224, 224, 3)
# (2622,)

# %% [markdown]
# ### Generate embeddings for all images (5 marks)
# - Write code to iterate through metadata and create embeddings for each image using `vgg_face_descriptor.predict()` and store in a list with name `embeddings`
#
# - If there is any error in reading any image in the dataset, fill the emebdding vector of that image with 2622-zeroes as the final embedding from the model is of length 2622.

# %%
metadata.shape[0]
# Out:
# 10770

# %%
embeddings = [np.zeros((metadata.shape[0], 2622))]
j=0
for i, m in enumerate(metadata):
  img_path = metadata[i].image_path()
  img = load_image(img_path)
  if img is not None:
      # Normalising pixel values from [0-255] to [0-1]: scale RGB values to interval [0,1]
      img = (img / 255.).astype(np.float32)

      img = cv2.resize(img, dsize = (224,224))

      # Obtain embedding vector for an image
      # Get the embedding vector for the above image using vgg_face_descriptor model and print the shape 

      embedding_vector = vgg_face_descriptor.predict(np.expand_dims(img, axis=0))[0]
  else:
      print("no image")
      embedding_vector = np.zeros(2622, )
  embeddings.append(embedding_vector)
  j+=1

print(j)
# Out:
# 10770

# %% [markdown]
# ### Function to calculate distance between given 2 pairs of images.
#
# - Consider distance metric as "Squared L2 distance"
# - Squared l2 distance between 2 points (x1, y1) and (x2, y2) = (x1-x2)^2 + (y1-y2)^2

# %%
def distance(emb1, emb2):
    return np.sum(np.square(emb1 - emb2))

# %% [markdown]
# #### Plot images and get distance between the pairs given below
# - 2, 3 and 2, 180
# - 30, 31 and 30, 100
# - 70, 72 and 70, 115

# %%
import matplotlib.pyplot as plt

def show_pair(idx1, idx2):
    plt.figure(figsize=(8,3))
    plt.suptitle(f'Distance = {distance(embeddings[idx1], embeddings[idx2]):.2f}')
    plt.subplot(121)
    plt.imshow(load_image(metadata[idx1].image_path()))
    plt.subplot(122)
    plt.imshow(load_image(metadata[idx2].image_path()));    

show_pair(2, 3)
show_pair(2, 180)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-43592ce1c48a> in <module>()
#       9     plt.imshow(load_image(metadata[idx2].image_path()));
#      10
# ---> 11 show_pair(2, 3)
#      12 show_pair(2, 180)
#
# <ipython-input-1-43592ce1c48a> in show_pair(idx1, idx2)
#       3 def show_pair(idx1, idx2):
#       4     plt.figure(figsize=(8,3))
# ----> 5     plt.suptitle(f'Distance = {distance(embeddings[idx1], embeddings[idx2]):.2f}')
#       6     plt.subplot(121)
#       7     plt.imshow(load_image(metadata[idx1].image_path()))
#
# NameError: name 'distance' is not defined

# %% [markdown]
# ### Create train and test sets (5 marks)
# - Create X_train, X_test and y_train, y_test
# - Use train_idx to seperate out training features and labels
# - Use test_idx to seperate out testing features and labels

# %%
train_idx = np.arange(metadata.shape[0]) % 9 != 0
# Out:
# array([ 0.03387297, -0.00404642, -0.0063194 , ..., -0.00015425,
#         0.00216459,  0.003674  ], dtype=float32)

# %%
np.arange(metadata.shape[0]) % 9
# Out:
# array([0, 1, 2, ..., 3, 4, 5])

# %%
train_idx = np.arange(metadata.shape[0]) % 9 != 0     #every 9th example goes in test data and rest go in train data
test_idx = np.arange(metadata.shape[0]) % 9 == 0

# one half as train examples of 10 identities
X_train = embeddings[train_idx]
# another half as test examples of 10 identities
X_test = embeddings[test_idx]

targets = np.array([m.name for m in metadata])
#train labels
y_train = targets[train_idx]
#test labels
y_test = targets[test_idx]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-0a829e8e2c78> in <module>()
#       3
#       4 # one half as train examples of 10 identities
# ----> 5 X_train = embeddings[train_idx]
#       6 # another half as test examples of 10 identities
#       7 X_test = embeddings[test_idx]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
test_idx
# Out:
# array([ True, False, False, ..., False, False, False])

# %% [markdown]
# ### Encode the Labels (3 marks)
# - Encode the targets
# - Use LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

#### Add your code here ####

# %% [markdown]
# ### Standardize the feature values (3 marks)
# - Scale the features using StandardScaler

# %%
# Standarize features
from sklearn.preprocessing import StandardScaler

#### Add your code here ####

# %% [markdown]
# ### Reduce dimensions using PCA (3 marks)
# - Reduce feature dimensions using Principal Component Analysis
# - Set the parameter n_components=128

# %%
from sklearn.decomposition import PCA

#### Add your code here ####

# %% [markdown]
# ### Build a Classifier (3 marks)
# - Use SVM Classifier to predict the person in the given image
# - Fit the classifier and print the score

# %%
from sklearn.svm import SVC

#### Add your code here ####

# %% [markdown]
# ### Test results (1 mark)
# - Take 10th image from test set and plot the image
# - Report to which person(folder name in dataset) the image belongs to

# %%
import warnings
# Suppress LabelEncoder warning
warnings.filterwarnings('ignore')

example_idx = 10

example_image = load_image(metadata[test_idx][example_idx].image_path())
example_prediction = #### Add your code here ####
example_identity = encoder.inverse_transform(example_prediction)[0]

plt.imshow(example_image)
plt.title(f'Identified as {example_identity}');
